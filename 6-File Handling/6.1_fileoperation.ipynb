# %% [markdown]
# ***File Operation - Read And Write Files***
#
# File handling is a crucial part of any programming language. Pyhton provides built-in functions and methods to read from and write to files, both text and binary. This lesson will cover the basics of the basics of file handling, including reading and writing text files and binary files.

# %%
## Read a whole file
with open('example.txt','r') as file:
    content=file.read()
    print(content)
# Out:
# Hello How are you?
# I am good
# Adarsh is my name
# Welcome to the course

# %%
## Read a file line by line
with open('example.txt','r') as file:
    for line in file:
        print(line.strip()) ## this strip() remove new line chracter
# Out:
# Hello How are you?
# I am good
# Adarsh is my name
# Welcome to the course

# %%
## Wrting a file(Overwriting)
with open('example.txt','w') as file:
    file.write('Hello World!\n')
    file.write('This is new line.')

# %%
## Write a file without OverWritting
with open('example.txt','a') as file:
    file.write("\nAppend operation taking place!\n")

# %%
## Writing a list of lines to a file
lines=['First line \n','Second line \n','Third line\n']
with open('example.txt','a') as file:
    file.writelines(lines)

# %%
## Binary files
# Write to a binary files
data = b'\x00\x01\x02\x03\x04'
with open('example.bin','wb') as file:
    file.write(data)

# %%
# read binary file
with open('example.bin','rb') as file:
    content=file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
# Read the content from source text file and write to a destination text file
# Copying a text file
with open('example.txt','r') as source_file:
    content = source_file.read()

with open('destination.txt','w') as destination_file:
    destination_file.write(content)

# %%
## Read a text file and count the number of lines, words and characters.
# counting lines, words, and characters in a text file

def count_text_file(file_path):
    with open(file_path,'r') as file:
        lines = file.readlines()
        line_count=len(lines)
        word_count=sum(len(line.split()) for line in lines)
        char_count=sum(len(line) for line in lines)
    return line_count, word_count, char_count

file_path='example.txt'
lines,words,characters=count_text_file(file_path)
print(f"Lines: {lines}, Words: {words}, Characters: {characters}")
# Out:
# Lines: 6, Words: 16, Characters: 98

# %% [markdown]
# The w+ in python is used to open a file for both reading and writing. If the file does not exist, it will be created. If the file exists, its content is truncated(i.e. the file is overwritten)

# %%
## Writing and then reading a file 
with open('example.txt','w+') as file:
    file.write("Hello world\n")
    file.write("This is a new line \n")
    
    # move the file cursor to the beginning 
    file.seek(0)
    
    # Read the content of the file 
    content=file.read()
    print(content)
# Out:
# Hello world
# This is a new line

# %%
## Writing a

# %%
## Writing a list of lines to a file
lines=['First line \n','Second line \n','Third line\n']
with open('example.txt','a') as file:

# %%
with open('example.txt','r') as f:
    print(f.read())
# Out:
# Hello How are you?
# I am good
# Adarsh is my name
# Welcome to the course

# %%
file_content=open('example.txt','r')
# print(file_content.read())
print(file_content.readline())
print(file_content.readlines())
# Out:
# Hello How are you?
#
# ['I am good\n', 'Adarsh is my name\n', 'Welcome to the course']

# %%
file_content=open("example.txt",'w')
file_content.write("Hello Adarsh")
f.close()

# %%
print(file_content.read())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(file_content.read())
#
# UnsupportedOperation: not readable
