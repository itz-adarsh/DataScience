# %%
## if statement
age=20
if age>=18:
    print("You are allowed to vote in the election")
# Out:
# You are allowed to vote in the election

# %%
## else statement
age=16
if age>=18:
    print("You are eleigible for voting")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
## elif - allows you to check multiple coditions

age=17
if age<13:
    print("You are a child")
elif age<18:
    print("You are a teenager")
else:
    print("You are adult")
# Out:
# You are a teenager

# %%
## Nested Condtional Statements
## if you can place one or more if, elif, or else statements inside another if, elif, pr else statement to create a nested conditional statements

## number even , odd , negative

num=int(input("Enter the number"))
if num>0:
    print("The number is positive")
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is zero or negative")
# Out:
# The number is positive
# The number is odd

# %%
## Practical example

## Determine if a year is a leap year using nested condition statement

year=int(input("Enter the year"))
if year%4==0:
    if year%100==0:
        if year%400==0:
            print(year,"is a leap year")
        else:
            print(year,"is not leap year")
    else:
        print(year,"is not a leap year")
else:
    print(year,"is not a leap year")
# Out:
# 2022 is not a leap year

# %%
## make a calculator using if elif else statement
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Enter operation (+, -,*, /): ")

#Perform the requested operation
if operation == '+':
    result = num1+num2
elif operation == '-':
     result = num1-num2
elif operation == '*':
     result = num1*num2
elif operation == '/':
    if num2 !=0:
       result = num1 / num2
    else:
       result = "Error! Division by zero."
else:
    result="Invalid operation."
print("Result:", result)
# Out:
# Result: 20.0

# %%
age = int(input("Enter your age: "))
is_student = input("Are you a student? (yes/no): ").lower()  # Converts the string to lowercase

if age < 5:
    price = "Free"
elif age <= 12:
    price = "$10"
elif age <= 17:
    if is_student == 'yes':
        price = "$12"
    else:
        price = "$15"
elif age <= 64:
    if is_student == 'yes':
        price = "$18"
    else:
        price = "$25"
else:
    price = "$20"

print("Ticket Price:", price)
# Out:
# Ticket Price: $18

# %%
a = int(input("Enter your age:"))
if(a>18):
    print("You are above the age of consent")
    print("Good for you")
elif(a<0):
    print("You are entering an invalid negative age")
elif(a==0):
    print("You are entering 0 which is not valid age")
else:
    print("You are below the age of consent")
    
print("End the program")
# Out:
# You are entering 0 which is not valid age
# End the program

# %%
## Multiple if statements
age = int(input("Enter your age: "))
if (age%2==0):
    print("The number is even")
if(a>18):
    print("You are above the age of consent")
    print("Good for you")
elif(a<0):
    print("You are entering an invalid negative age")
elif(a==0):
    print("You are entering 0 which is not valid age")
else:
    print("You are below the age of consent")
    
print("End the program")
# Out:
# The number is even
# You are entering 0 which is not valid age
# End the program

# %%
a1=int(input("Enter number 1: "))
a2=int(input("Enter number 2: "))
a3=int(input("Enter number 2: "))
a4=int(input("Enter number 2: "))

if(a1>a2 and a1>a3 and a1>a4):
    print("Greatest number is a1:", a1)
elif(a2>a1 and a2>a3 and a2>a4):
    print("Greatest number is a2:", a2)
elif(a3>a1 and a3>a2 and a3>a4):
    print("Greatest number is a3:", a3)
elif(a4>a1 and a4>a2 and a4>a3):
    print("Greatest number is a4:", a4)
# Out:
# Greatest number is a3: 89

# %%
marks1 = int(input("Enter Marks 1: "))
marks2 = int(input("Enter Marks 2: "))
marks3 = int(input("Enter Marks 3: "))
## check for total_percentage 

total_percentage = (100*(marks1+marks2+marks3))/300
if(total_percentage>=40 and marks1>=33 and marks2>=33 and marks3>=33):
    print("You are passed",total_percentage)
else:
    print("You failed, try again next year",total_percentage)
# Out:
# You failed, try again next year 41.333333333333336

# %%
p1 = "Make a lot of money"
p2 = "buy now"
p3 = "subscribe this"
p4 = "click this"

message = input("Enter your comment:")

if(p1 in message) or (p2 in message) or (p3 in message) or (p4 in message):   ## in is used to check if a substring is present in a string 
    print("This comment is spam") 
else:
    print("This is not spam")
# Out:
# This comment is spam

# %%
username = input("Enter your username: ")
if(len(username)<10):
    print("Your username contains less than 10 characters")
else:
    print("Your username is valid")
# Out:
# All is well!

# %%
l = ["Harry", "Larry", "Carry", "Marry"]
name = input("Enter your name: ")
if(name in l):
    print("Your name is present in the list")
else:
    print("Your name is not present in the list")
# Out:
# Your name is present in the list

# %%
marks = int(input("Enter your marks: "))
if (marks<=100 and marks>=90):
    grade = "Ex"
elif (marks<90 and marks>=80):
    grade = "A"
elif (marks<80 and marks>=70):
    grade = "B"
elif (marks<70 and marks>=60):
    grade = "C"
elif (marks<60 and marks>=50):
    grade = "D"
elif (marks<50):
    grade = "F"
    
print("Your grade is:", grade)
# Out:
# Your grade is: B

# %%
##post = "Hey harry bhai is good Harry is very good and harry is great"
post = input("Enter your post: ")
if ("harry".lower() in post.lower()): ## here lower is used to convert the string to lowercase so that we can check for the presence of "harry" in the post regardless of the case (uppercase or lowercase) used in the post.
    print("This post is talking about harry")
# Out:
# This post is talking about harry
