# %%
## Arithmatic operation

a=10
b=6
add_result=a+b
sub_result=a-b
mul_result=a*b
div_result=a/b
floor_div_result=a//b  ## floor division
modulus_result=a%b     ## modulus operation
exponent_result=a**b
print("Addition result:", add_result)
print("Subtraction result:", sub_result)
print("Multiplication result:", mul_result)
print("Division result:", div_result)
print("Floor division result:", floor_div_result)
print("Modulus result:", modulus_result)
print("Exponent result:", exponent_result)
# Out:
# Addition result: 16
# Subtraction result: 4
# Multiplication result: 60
# Division result: 1.6666666666666667
# Floor division result: 1
# Modulus result: 4
# Exponent result: 1000000

# %%
10/5
# Out:
# 2.0

# %%
21/5
# Out:
# 4.2

# %%
21//5 ## this floor division
# Out:
# 4

# %% [markdown]
# ***Comparison Operator***

# %%
## Comparison operator

a=10
b=10
a==b
# Out:
# True

# %%
str1="Adarsh"
str2="Adarsh"
str3="adarsh"
print(str1==str2)
print(str1==str3)
# Out:
# True
# False

# %%
## Not Equal to !=
str1!=str2
# Out:
# False

# %%
str1!=str3
# Out:
# True

# %%
## Greater than >
## Less than <
num1=45
num2=55
print(num1>num2)
print(num1<num2)
# Out:
# False
# True

# %%
## Greater than equal to
number1=45
numebr2=45
number1>numebr2
# Out:
# False

# %%
## Less than equal to
number1=45
number2=45
number1<number2
# Out:
# False

# %% [markdown]
# ***Logical Operator***

# %%
## AND, OR, NOT
X=True
Y=True
result = X and Y
print(result)
# Out:
# True

# %%
X=False
Y=True
result = X and Y
print(result)
# Out:
# False

# %%
X=True
Y=True
result = X or Y
print(result)
# Out:
# True

# %%
X=True
Y=False
result = X or Y
print(result)
# Out:
# True

# %%
X=False
Y=False
result = X or Y
print(result)
# Out:
# False

# %%
X=False
not X
# Out:
# True

# %%
a = int(input("Enter number 1: "))
b = int(input("Enter number 2: "))
print("Number a is: ", a)
print("Number b is: ", b)
print("Sum is ", a+b)
print("Square of number 1 ", a**2)
# Out:
# Number a is:  7
# Number b is:  5
# Sum is  12
# Square of number 1  49
